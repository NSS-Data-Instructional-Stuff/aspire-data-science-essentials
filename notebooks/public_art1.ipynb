# %% [markdown]
# # Introduction to pandas
#
# In this notebook, you'll get familiar with the basics of reading in and getting acquainted with data using the `pandas` library.

# %% [markdown]
# ### Import the `pandas` library, aliased as `pd`.

# %%
import pandas as pd

# %% [markdown]
# ### Let's explore these pandas methods, attributes, and accessors
#  - .head()
#  * .tail()
#  * .shape
#  * .info()
#  * .dtypes
#  - .columns
#  - .drop()
#  * .unique()
#  * .nunique()
#  * .value_counts()]].
#  - .query()
#  - .rename()
#  - .loc[]
#  - [[]]

# %% [markdown]
# ### Read in the public art data and examine the head, tail, shape, info and dtypes

# %%
art = pd.read_csv('../data/public_art.csv')

# %% [markdown]
# To inspect a portion of the dataframe, you can use `.head()` (to see the first few rows) or `.tail()` (to see the last few rows).

# %%
art.head(2)
# Out:
#                              Title Last Name First Name  \
# 0          [Cross Country Runners]     Frost      Miley
# 1  [Fourth and Commerce Sculpture]    Walker        Lin
#
#                             Location  Medium       Type Description  Latitude  \
# 0     4001 Harding Rd., Nashville TN  Bronze  Sculpture         NaN  36.12856
# 1  333 Commerce Street, Nashville TN     NaN  Sculpture         NaN  36.16234
#
#    Longitude        Mapped Location
# 0  -86.83660   (36.12856, -86.8366)
# 1  -86.77774  (36.16234, -86.77774)

# %%
art.tail(2)
# Out:
#                                                  Title Last Name First Name  \
# 130                            Women Suffrage Memorial   LeQuire       Alan
# 131  Youth Opportunity Center-STARS Nashville - Pea...   Rudloff      Andee
#
#                                Location                Medium       Type  \
# 130  600 Charlotte Avenue, Nashville TN      Bronze sculpture  Sculpture
# 131                 1704 Charlotte Ave.  House paint on vinyl      Mural
#
#     Description  Latitude  Longitude        Mapped Location
# 130         NaN  36.16527  -86.78382  (36.16527, -86.78382)
# 131         NaN  36.15896  -86.79900    (36.15896, -86.799)

# %%
art.shape
# Out:
# (132, 10)

# %%
art.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            132 non-null    object
#  1   Last Name        132 non-null    object
#  2   First Name       122 non-null    object
#  3   Location         131 non-null    object
#  4   Medium           128 non-null    object
#  5   Type             132 non-null    object
#  6   Description      87 non-null     object
#  7   Latitude         132 non-null    float64
#  8   Longitude        132 non-null    float64
#  9   Mapped Location  132 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 10.4+ KB

# %% [markdown]
# **What do you notice?**
#
# Quite a few missing Desciptions, 10 missing First Names, a few missing Mediums, and one missing Location.

# %%
art.dtypes
# Out:
# Title               object
# Last Name           object
# First Name          object
# Location            object
# Medium              object
# Type                object
# Description         object
# Latitude           float64
# Longitude          float64
# Mapped Location     object
# dtype: object

# %% [markdown]
# You may notice that most of the columns are "objects". This is the datatype that `pandas` uses for text data.
#
# The float64 datatype is a numeric datatype that can handle decimal values.

# %%
art.columns
# Out:
# Index(['Title', 'Last Name', 'First Name', 'Location', 'Medium', 'Type',
#        'Description', 'Latitude', 'Longitude', 'Mapped Location'],
#       dtype='object')

# %% [markdown]
# Since the Mapped Location information is already contained in the Latitude and Longitude columns, you really don't need to store it twice. You can use the `.drop()` method to get rid of that column.

# %%
art.drop(columns='Mapped Location')
# Out:
#                                                  Title  \
# 0                              [Cross Country Runners]
# 1                      [Fourth and Commerce Sculpture]
# 2                                  12th & Porter Mural
# 3                                    A Splash of Color
# 4                                 A Story of Nashville
# ..                                                 ...
# 127                                 We Are Our Stories
# 128                                Welcome to Flatrock
# 129                                         Wind Reeds
# 130                            Women Suffrage Memorial
# 131  Youth Opportunity Center-STARS Nashville - Pea...
#
#                                            Last Name  \
# 0                                              Frost
# 1                                             Walker
# 2                                            Kennedy
# 3           Stevenson and Stanley and ROFF (Harroff)
# 4                                             Ridley
# ..                                               ...
# 127  Omari Booker & The REAL Program at Oasis Center
# 128                                           Cooper
# 129                                             Kahn
# 130                                          LeQuire
# 131                                          Rudloff
#
#                     First Name                            Location  \
# 0                        Miley      4001 Harding Rd., Nashville TN
# 1                          Lin   333 Commerce Street, Nashville TN
# 2                          Kim                   114 12th Avenue N
# 3    Doug and Ronnica and Lynn                    616 17th Ave. N.
# 4                         Greg     615 Church Street, Nashville TN
# ..                         ...                                 ...
# 127                        NaN              1037 28th Avenue North
# 128                    Michael                 3756 Nolensville Rd
# 129                        Ned      1 Terminal Drive, Nashville TN
# 130                       Alan  600 Charlotte Avenue, Nashville TN
# 131                      Andee                 1704 Charlotte Ave.
#
#                                                 Medium       Type  \
# 0                                               Bronze  Sculpture
# 1                                                  NaN  Sculpture
# 2                     Porter all-weather outdoor paint      Mural
# 3    Steel, brick, wood, and fabric on frostproof c...      Mural
# 4                             Hammered copper repousse     Frieze
# ..                                                 ...        ...
# 127                   acrylic & spray paint on plywood      Mural
# 128                         Silicate paint on concrete      Mural
# 129                                    Aluminum panels  Sculpture
# 130                                   Bronze sculpture  Sculpture
# 131                               House paint on vinyl      Mural
#
#                                            Description   Latitude  Longitude
# 0                                                  NaN  36.128560 -86.836600
# 1                                                  NaN  36.162340 -86.777740
# 2    Kim Kennedy is a musician and visual artist wh...  36.157900 -86.788170
# 3    Painted wooden hoop dancer on a twenty foot po...  36.162020 -86.799750
# 4    Inside the Grand Reading Room, this is a serie...  36.162150 -86.782050
# ..                                                 ...        ...        ...
# 127  "We Are Our Stories" is a public art project t...  36.165101 -86.822209
# 128  Trompe L'oeil animals and architectural stonew...  36.090820 -86.734450
# 129  Hinged aluminum panels that cover a wall of th...  36.134690 -86.667770
# 130                                                NaN  36.165270 -86.783820
# 131                                                NaN  36.158960 -86.799000
#
# [132 rows x 9 columns]

# %%
art.head(2)
# Out:
#                              Title Last Name First Name  \
# 0          [Cross Country Runners]     Frost      Miley
# 1  [Fourth and Commerce Sculpture]    Walker        Lin
#
#                             Location  Medium       Type Description  Latitude  \
# 0     4001 Harding Rd., Nashville TN  Bronze  Sculpture         NaN  36.12856
# 1  333 Commerce Street, Nashville TN     NaN  Sculpture         NaN  36.16234
#
#    Longitude        Mapped Location
# 0  -86.83660   (36.12856, -86.8366)
# 1  -86.77774  (36.16234, -86.77774)

# %% [markdown]
# What happened? We failed to save the result of dropping the column. We need to assign the result back to the art dataframe.

# %%
art = art.drop(columns = 'Mapped Location')

# %% [markdown]
# What are the different Types of artwork in this dataset?

# %%
art['Type'].unique()
# Out:
# array(['Sculpture', 'Mural', 'Frieze', 'Monument', 'Mobile', 'Furniture',
#        'Mosaic', 'Relief', 'Stained Glass', 'Bronzes',
#        'Sculpture/Fountain', 'Various', 'Street Art', 'mural', 'Fountain',
#        'Multipart'], dtype=object)

# %% [markdown]
# If you only care about the _number_ of unique values in a colmn, you can use `.nunique`.
#
# For example, if you want to know the number of artist last names:

# %%
art['Last Name'].nunique()
# Out:
# 82

# %% [markdown]
# Which is the most popular Type?

# %%
art['Type'].value_counts()
# Out:
# Sculpture             61
# Mural                 38
# Monument              16
# Mosaic                 2
# Various                2
# Mobile                 2
# Frieze                 2
# Fountain               1
# Street Art             1
# Furniture              1
# Stained Glass          1
# Multipart              1
# Bronzes                1
# Sculpture/Fountain     1
# Relief                 1
# mural                  1
# Name: Type, dtype: int64

# %% [markdown]
# What if you want to see all of the Murals? You can slice a dataframe using the `.query` method.

# %%
art.query('Type == "Mural"')
# Out:
#                                                  Title  \
# 2                                  12th & Porter Mural
# 3                                    A Splash of Color
# 5                             Aerial Innovations Mural
# 10                                          April Baby
# 16                             Bicycle Bus-Green Fleet
# 19                       Building a Positive Community
# 26                                         Cool Fences
# 28                               Demonbreun Hill Mural
# 29                                   Dragon Wall Mural
# 30                                      Eastside Mural
# 39                                        Gone Fishing
# 40                           Happy Times at The Arcade
# 42                             Hillsboro Village Mural
# 44                     I BELIEVE IN NASHVILLE 12 South
# 45               I BELIEVE IN NASHVILLE East Nashville
# 46              I BELIEVE IN NASHVILLE North Nashville
# 47                                          In Concert
# 54                                   Johnny Cash Mural
# 56                                   Lane Motor Museum
# 57                               Les Paul Guitar Mural
# 58                                   Phillips Toy Mart
# 61                     M&M Furniture-Riverside Village
# 63                                     Maybelle Carter
# 64                                           Migration
# 66   Nashville, A History through Maps and Aerial V...
# 69                               Our Past, Your Future
# 75                             Piecing It All Together
# 81                                       Rolling Hills
# 84                     Safe Haven Family Shelter Mural
# 97                                          Stay Tuned
# 111                                The Waterfall Mural
# 116                                           Tomatoes
# 118                                      Two Musicians
# 123                                   Voices Gathering
# 124                                             Volume
# 127                                 We Are Our Stories
# 128                                Welcome to Flatrock
# 131  Youth Opportunity Center-STARS Nashville - Pea...
#
#                                              Last Name  \
# 2                                              Kennedy
# 3             Stevenson and Stanley and ROFF (Harroff)
# 5                                              Rudloff
# 10                                            Prestwod
# 16                                             Rudloff
# 19                          Healing Arts Project, Inc.
# 26                                               Guion
# 28                                               Deese
# 29                                   Randolf and Glick
# 30                Sterling Goller-Brown.  Ian Lawrence
# 39                                              Cooper
# 40                                              Cooper
# 42                                             Rudloff
# 44                                            Saporiti
# 45                                            Saporiti
# 46                                            Saporiti
# 47                                             Purcell
# 54              Bryan Deese, Audie Adams, Ryan Shrader
# 56                                              Cooper
# 57                                              Hughes
# 58                                              Cooper
# 61                                             Rudloff
# 63                              Brian Law / Jenna Colt
# 64                                               Prado
# 66                                                Haas
# 69                Sterling Goller-Brown.  Ian Lawrence
# 75                                              Cooper
# 81                                            Ulibarri
# 84                                             Rudloff
# 97                                            Saporiti
# 111                                              Deese
# 116  Sterling Goller-Brown and Ian Lawrence, co-cre...
murals = art.query('Type == "Mural"')
murals.shape
# Out:
# (38, 9)

# %% [markdown]
# Who is the most prolific mural painter in Nashville?

# %%
murals['Last Name'].value_counts()
# Out:
# Rudloff                                                6
# Cooper                                                 6
# Saporiti                                               5
# Sterling Goller-Brown.  Ian Lawrence                   3
# Deese                                                  2
# Healing Arts Project, Inc.                             1
# Bryan Deese, Audie Adams, Ryan Shrader                 1
# Williams                                               1
# Guion                                                  1
# Prado                                                  1
# Stevenson and Stanley and ROFF (Harroff)               1
# Kennedy                                                1
# Purcell                                                1
# Prestwod                                               1
# Randolf and Glick                                      1
# Hughes                                                 1
# Omari Booker & The REAL Program at Oasis Center        1
# Ulibarri                                               1
# Sterling Goller-Brown and Ian Lawrence, co-creators    1
# Brian Law / Jenna Colt                                 1
# Haas                                                   1
# Name: Last Name, dtype: int64

# %% [markdown]
# Let's see all of the artwork that Cooper painted.

# %%
murals.query('Last Name == "Cooper"')
# Out:
# Traceback (most recent call last):
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-72-fa4b1270cb44>", line 1, in <module>
#     murals.query('Last Name == "Cooper"')
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/computation/eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 371, in visit
#     raise e
#
#   File "/home/michael/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/home/michael/anaconda3/lib/python3.7/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     Last Name =="Cooper"
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Oh no. What went wrong?
#
# The `.query` method does not like spaces in column names. These can be escaped by using backticks around the column name.

# %%
murals.query('`Last Name` == "Cooper"')
# Out:
#                          Title Last Name First Name  \
# 39                Gone Fishing    Cooper    Michael
# 40   Happy Times at The Arcade    Cooper    Michael
# 56           Lane Motor Museum    Cooper    Michael
# 58           Phillips Toy Mart    Cooper    Michael
# 75     Piecing It All Together    Cooper    Michael
# 128        Welcome to Flatrock    Cooper    Michael
#
#                                           Location  \
# 39                              Church Street Park
# 40   In the Alley between 4th and 5th off of Union
# 56                           702 Murfreesboro Pike
# 58                               5207 Harding Pike
# 75                 600 Church Street, Nashville TN
# 128                            3756 Nolensville Rd
#
#                                              Medium   Type  \
# 39                                 Acrylic on Brick  Mural
# 40       Silicate paint on brick and concrete block  Mural
# 56   Acrylic on Brick; acrylic on metal wall panels  Mural
# 58                               Acrylic on Drywall  Mural
# 75                                Painting on Stone  Mural
# 128                      Silicate paint on concrete  Mural
#
#                                            Description  Latitude  Longitude
# 39   Just having some fun with Trompe L'oeil balconies  36.16298  -86.78184
# 40        Trompe L'oeil artwork celebrating The Arcade  36.16470  -86.78043
# 56   Trompe l'oeil scene on garage wall; custom "po...  36.14034  -86.73440
# 58                     Planes, trains and automobiles!  36.10255  -86.86970
# 75                                                 NaN  36.16281  -86.78186
# 128  Trompe L'oeil animals and architectural stonew...  36.09082  -86.73445

# %% [markdown]
# But another option is to rename our columns to remove the spaces.

# %%
art.columns
# Out:
# Index(['Title', 'Last Name', 'First Name', 'Location', 'Medium', 'Type',
#        'Description', 'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# Column names can be set either by specifying a **list** of names:

# %%
art.columns = ['title', 'last_name', 'first_name', 'location', 'medium',
              'type', 'description', 'lat', 'lng']

# %% [markdown]
# or by using the `.rename` method and passing in a **dictionary**. A dictionary is a collection of key-value pairs.

# %%
art = art.rename(columns = {'Title': 'title', 
                            'Last Name': 'last_name', 
                            'First Name': 'first_name',
                            'Location': 'loc', 
                            'Medium': 'medium', 
                            'Desccription': 'desc', 
                            'Latiitude': 'lat', 
                            'Longitude': 'lng'})

# %% [markdown]
# So now you can try to slice the murals dataframe using the new column name.

# %%
murals.query('last_name == "Cooper"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/anaconda3/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# ~/anaconda3/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'last_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'last_name'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-77-64d73db9204e> in <module>
# ----> 1 murals.query('last_name == "Cooper"')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     414     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     415         if left is None:
# --> 416             left = self.visit(node.left, side="left")
#     417         if right is None:
#     418             right = self.visit(node.right, side="right")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'last_name' is not defined

# %% [markdown]
# Oops, what went wrong? Just because we renamed the art dataframe doesn't mean the murals one will be renamed as well. Fix the issue so that the query above will work.

# %%
murals = murals.rename(columns = {'Title': 'title', 
                            'Last Name': 'last_name', 
                            'First Name': 'first_name',
                            'Location': 'loc', 
                            'Medium': 'medium', 
                            'Desccription': 'desc()', 
                            'Latiitude': 'lat', 
                            'Longitude': 'lng'})

# %%
murals.query('last_name == "Cooper"')
# Out:
#                          title last_name first_name  \
# 39                Gone Fishing    Cooper    Michael
# 40   Happy Times at The Arcade    Cooper    Michael
# 56           Lane Motor Museum    Cooper    Michael
# 58           Phillips Toy Mart    Cooper    Michael
# 75     Piecing It All Together    Cooper    Michael
# 128        Welcome to Flatrock    Cooper    Michael
#
#                                                loc  \
# 39                              Church Street Park
# 40   In the Alley between 4th and 5th off of Union
# 56                           702 Murfreesboro Pike
# 58                               5207 Harding Pike
# 75                 600 Church Street, Nashville TN
# 128                            3756 Nolensville Rd
#
#                                              medium   Type  \
# 39                                 Acrylic on Brick  Mural
# 40       Silicate paint on brick and concrete block  Mural
# 56   Acrylic on Brick; acrylic on metal wall panels  Mural
# 58                               Acrylic on Drywall  Mural
# 75                                Painting on Stone  Mural
# 128                      Silicate paint on concrete  Mural
#
#                                            Description  Latitude       lng
# 39   Just having some fun with Trompe L'oeil balconies  36.16298 -86.78184
# 40        Trompe L'oeil artwork celebrating The Arcade  36.16470 -86.78043
# 56   Trompe l'oeil scene on garage wall; custom "po...  36.14034 -86.73440
# 58                     Planes, trains and automobiles!  36.10255 -86.86970
# 75                                                 NaN  36.16281 -86.78186
# 128  Trompe L'oeil animals and architectural stonew...  36.09082 -86.73445

# %%
murals['last_name'].value_counts()
# Out:
# Rudloff                                                6
# Cooper                                                 6
# Saporiti                                               5
# Sterling Goller-Brown.  Ian Lawrence                   3
# Deese                                                  2
# Healing Arts Project, Inc.                             1
# Bryan Deese, Audie Adams, Ryan Shrader                 1
# Williams                                               1
# Guion                                                  1
# Prado                                                  1
# Stevenson and Stanley and ROFF (Harroff)               1
# Kennedy                                                1
# Purcell                                                1
# Prestwod                                               1
# Randolf and Glick                                      1
# Hughes                                                 1
# Omari Booker & The REAL Program at Oasis Center        1
# Ulibarri                                               1
# Sterling Goller-Brown and Ian Lawrence, co-creators    1
# Brian Law / Jenna Colt                                 1
# Haas                                                   1
# Name: last_name, dtype: int64

# %% [markdown]
# Take another look at the murals dataframe and notice that Sterling Goller-Brown and Ian Lawrence collaborated on multiple murals, but these are stored in the dataframe differently. What if we want to slice down and find these rows?

# %%
goller_lawrence = ['Sterling Goller-Brown.  Ian Lawrence', 'Sterling Goller-Brown and Ian Lawrence, co-creators']

# %%
murals.query('last_name in @goller_lawrence')
# Out:
#                      title                                          last_name  \
# 30          Eastside Mural               Sterling Goller-Brown.  Ian Lawrence
# 69   Our Past, Your Future               Sterling Goller-Brown.  Ian Lawrence
# 116               Tomatoes  Sterling Goller-Brown and Ian Lawrence, co-cre...
# 118          Two Musicians               Sterling Goller-Brown.  Ian Lawrence
#
#     first_name                            loc          medium   Type  \
# 30         NaN               1008 Forrest Ave     Spray Paint  Mural
# 69         NaN              1524 Gallatin Ave     Spray Paint  Mural
# 116        NaN  701 Porter Rd at Eastland Ave  paint on brick  Mural
# 118        NaN               1008 Forrest Ave     Spray Paint  Mural
#
#     Description   Latitude        lng
# 30          NaN  36.178323 -86.750240
# 69          NaN  36.194354 -86.743985
# 116    Tomatoes  36.182437 -86.733449
# 118         NaN  36.178323 -86.750240

# %% [markdown]
# Another method of slicing a dataframe is by using `.loc`.
#
# We can fetch rows based on their **index** values (the first column of the dataframe).

# %%
art.loc[20]
# Out:
# title                                                    Can-Do
# last_name                                       Lucking-Reilley
# first_name                                                 Mary
# location       Corner of 12th Ave S & Sevier Park, Nashville TN
# medium                                            Painted metal
# type                                                  Sculpture
# description            Trash can created by artist and children
# lat                                                     36.1216
# lng                                                    -86.7903
# Name: 20, dtype: object

# %% [markdown]
# You can fetch a range of rows:

# %%
art.loc[20:25]
# Out:
#                                 title        last_name     first_name  \
# 20                             Can-Do  Lucking-Reilley           Mary
# 21                        Chet Atkins            Faxon        Russell
# 22  Children's Chairs For The Seasons           McGraw         Deloss
# 23               Confederate Memorial           Nicoll          Carlo
# 24       Confederate Private Monument           Zolnay  George Julian
# 25                         Confluence        Medwedeff           John
#
#                                              location  \
# 20   Corner of 12th Ave S & Sevier Park, Nashville TN
# 21  Corner of Fifth Avenue North and Union Street,...
# 22                    615 Church Street, Nashville TN
# 23                    1101 Lebanon Pike, Nashville TN
# 24                 2500 West End Avenue, Nashville TN
# 25                               1515 Fifth Ave North
#
#                                          medium       type  \
# 20                                Painted metal  Sculpture
# 21  Bronze stool and guitar on a granite plynth  Sculpture
# 22                 Mixed Media - wood and paint  Furniture
# 23                      Marble on barre granite   Monument
# 24       Bronze on a limestone and granite base   Monument
# 25                                        Steel  Sculpture
#
#                                           description       lat       lng
# 20           Trash can created by artist and children  36.12161 -86.79027
# 21  A sculpture of a young Chet Atkins seated on a...  36.16466 -86.78102
# 22                  chairs depicting the four seasons  36.16215 -86.78205
# 23                                                NaN  36.14883 -86.73239
# 24  A seated portrait of Sam Davis, a boy hero of ...  36.14788 -86.81261
# 25                                                NaN  36.17902 -86.79186

# %% [markdown]
# You can also fetch only columns you're interested in by specifying them by name.

# %%
art.loc[20:25, ['title', 'last_name', 'medium']]
# Out:
#                                 title        last_name  \
# 20                             Can-Do  Lucking-Reilley
# 21                        Chet Atkins            Faxon
# 22  Children's Chairs For The Seasons           McGraw
# 23               Confederate Memorial           Nicoll
# 24       Confederate Private Monument           Zolnay
# 25                         Confluence        Medwedeff
#
#                                          medium
# 20                                Painted metal
# 21  Bronze stool and guitar on a granite plynth
# 22                 Mixed Media - wood and paint
# 23                      Marble on barre granite
# 24       Bronze on a limestone and granite base
# 25                                        Steel

# %% [markdown]
# It's also possible to slice down to a list of columns using double brackets [[ ]]:

# %%
art[['title', 'type', 'description']]
# Out:
#                                                  title       type  \
# 0                              [Cross Country Runners]  Sculpture
# 1                      [Fourth and Commerce Sculpture]  Sculpture
# 2                                  12th & Porter Mural      Mural
# 3                                    A Splash of Color      Mural
# 4                                 A Story of Nashville     Frieze
# ..                                                 ...        ...
# 127                                 We Are Our Stories      Mural
# 128                                Welcome to Flatrock      Mural
# 129                                         Wind Reeds  Sculpture
# 130                            Women Suffrage Memorial  Sculpture
# 131  Youth Opportunity Center-STARS Nashville - Pea...      Mural
#
#                                            description
# 0                                                  NaN
# 1                                                  NaN
# 2    Kim Kennedy is a musician and visual artist wh...
# 3    Painted wooden hoop dancer on a twenty foot po...
# 4    Inside the Grand Reading Room, this is a serie...
# ..                                                 ...
# 127  "We Are Our Stories" is a public art project t...
# 128  Trompe L'oeil animals and architectural stonew...
# 129  Hinged aluminum panels that cover a wall of th...
# 130                                                NaN
# 131                                                NaN
#
# [132 rows x 3 columns]

# %% [markdown]
# And finally, you can slice based on a condition, similar to using `.query`.

# %%
art.loc[art['last_name'] == 'Faxon']
# Out:
#                                title last_name first_name  \
# 9                       Anticipation     Faxon    Russell
# 17                   Blowing Bubbles     Faxon    Russell
# 18                    Breaking Bread     Faxon    Russell
# 21                       Chet Atkins     Faxon    Russell
# 31   Ed and Bernice Johnson and Mary     Faxon    Russell
# 51               Isabelle and Calvin     Faxon    Russell
# 67                           Oh, Roy     Faxon    Russell
# 95               St. Vincent de Paul     Faxon    Russell
# 101    Tennessee Korean War Memorial     Faxon    Russell
# 108                      The Readers     Faxon    Russell
#
#                                               location  \
# 9                   505 Deaderick Street, Nashville TN
# 17                     4715 Harding Pike, Nashville TN
# 18                                   705 Drexel Street
# 21   Corner of Fifth Avenue North and Union Street,...
# 31                     1900 Belmont Blvd, Nashville TN
# 51                               1718 Patterson Street
# 67                         116 5th Ave N, Nashville TN
# 95                     2216 State Street, Nashville TN
# 101                 301 6th Avenue North, Nashville TN
# 108                      3701 Benham Avenue, Nashville
#
#                                                 medium       type  \
# 9                                     Cold cast bronze  Sculpture
# 17                                              Bronze  Sculpture
# 18                                              bronze  Sculpture
# 21         Bronze stool and guitar on a granite plynth  Sculpture
# 31                                              Bronze  Sculpture
# 51                             bronze on granite bench  Sculpture
# 67                                              Bronze  Sculpture
# 95                                        Hollow metal  Sculpture
# 101  Bronze sculpture on bronze base with black gra...   Monument
# 108                             bronze on bronze bench  Sculpture
#
#                                            description       lat       lng
# 9    A statue of a woman with legs crossed sitting ...  36.16489 -86.78184
# 17                                                 NaN  36.11975 -86.85343
# 18       The work represents the principal of sharing.  36.15203 -86.77849
# 21   A sculpture of a young Chet Atkins seated on a...  36.16466 -86.78102
# 31                                                 NaN  36.13264 -86.79473
# 51                                                 NaN  36.15759 -86.79837
# 67   Minnie Pearl and Roy Acuff seated on a bench i...  36.16151 -86.77816
# 95   De Paul wears long robes and a skull cap.  He ...  36.15234 -86.80603
# 101  Two male figures dressed in combat fatigues an...  36.16414 -86.78289
# 108                                                NaN  36.10997 -86.80924

# %% [markdown]
# Note that to slice to values in a list, you can use `.isin`.

# %%
art.loc[art['last_name'].isin(goller_lawrence)]
# Out:
#                      title                                          last_name  \
# 30          Eastside Mural               Sterling Goller-Brown.  Ian Lawrence
# 69   Our Past, Your Future               Sterling Goller-Brown.  Ian Lawrence
# 116               Tomatoes  Sterling Goller-Brown and Ian Lawrence, co-cre...
# 118          Two Musicians               Sterling Goller-Brown.  Ian Lawrence
#
#     first_name                       location          medium   type  \
# 30         NaN               1008 Forrest Ave     Spray Paint  Mural
# 69         NaN              1524 Gallatin Ave     Spray Paint  Mural
# 116        NaN  701 Porter Rd at Eastland Ave  paint on brick  Mural
# 118        NaN               1008 Forrest Ave     Spray Paint  Mural
#
#     description        lat        lng
# 30          NaN  36.178323 -86.750240
# 69          NaN  36.194354 -86.743985
# 116    Tomatoes  36.182437 -86.733449
# 118         NaN  36.178323 -86.750240

# %% [markdown]
# Finally, you can negate a condition by adding a tilde ~ before that condition. So if you want to find all murals not paineted by Goller-Brown and Lawrence:

# %%
murals.loc[~murals['last_name'].isin(goller_lawrence)]
# Out:
#                                                  title  \
# 2                                  12th & Porter Mural
# 3                                    A Splash of Color
# 5                             Aerial Innovations Mural
# 10                                          April Baby
# 16                             Bicycle Bus-Green Fleet
# 19                       Building a Positive Community
# 26                                         Cool Fences
# 28                               Demonbreun Hill Mural
# 29                                   Dragon Wall Mural
# 39                                        Gone Fishing
# 40                           Happy Times at The Arcade
# 42                             Hillsboro Village Mural
# 44                     I BELIEVE IN NASHVILLE 12 South
# 45               I BELIEVE IN NASHVILLE East Nashville
# 46              I BELIEVE IN NASHVILLE North Nashville
# 47                                          In Concert
# 54                                   Johnny Cash Mural
# 56                                   Lane Motor Museum
# 57                               Les Paul Guitar Mural
# 58                                   Phillips Toy Mart
# 61                     M&M Furniture-Riverside Village
# 63                                     Maybelle Carter
# 64                                           Migration
# 66   Nashville, A History through Maps and Aerial V...
# 75                             Piecing It All Together
# 81                                       Rolling Hills
# 84                     Safe Haven Family Shelter Mural
# 97                                          Stay Tuned
# 111                                The Waterfall Mural
# 123                                   Voices Gathering
# 124                                             Volume
# 127                                 We Are Our Stories
# 128                                Welcome to Flatrock
# 131  Youth Opportunity Center-STARS Nashville - Pea...
#
#                                            last_name  \
# 2                                            Kennedy
# 3           Stevenson and Stanley and ROFF (Harroff)
# 5                                            Rudloff
# 10                                          Prestwod
# 16                                           Rudloff
# 19                        Healing Arts Project, Inc.
# 26                                             Guion
# 28                                             Deese
# 29                                 Randolf and Glick
# 39                                            Cooper
# 40                                            Cooper
# 42                                           Rudloff
# 44                                          Saporiti
# 45                                          Saporiti
# 46                                          Saporiti
# 47                                           Purcell
# 54            Bryan Deese, Audie Adams, Ryan Shrader
# 56                                            Cooper
# 57                                            Hughes
# 58                                            Cooper
# 61                                           Rudloff
# 63                            Brian Law / Jenna Colt
# 64                                             Prado
# 66                                              Haas
# 75                                            Cooper
# 81                                          Ulibarri
# 84                                           Rudloff
# 97                                          Saporiti
# 111                                            Deese
# 123                                         Williams
# 124                                         Saporiti
# 127  Omari Booker & The REAL Program at Oasis Center
# 128                                           Cooper
# 131                                          Rudloff
#
#                     first_name  \
# 2                          Kim
# 3    Doug and Ronnica and Lynn
# 5                        Andee
# 10                        Seth
# 16                       Andee
# 19        Healing Arts Project
# 26                       Scott
# 28                       Bryan
# 29              Adam and David
# 39                     Michael
# 40                     Michael
# 42                       Andee
# 44                      Adrien
# 45                      Adrien
# 46                      Adrien
# 47                       Randy
# 54                         NaN
# 56                     Michael
# 57                      Milree
# 58                     Michael
# 61                       Andee
# 63                         NaN
# 64                       Jairo
# 66                     Richard
# 75                     Michael
# 81                       Jerry
# 84                       Andee
# 97                      Adrien
# 111                      Bryan
# 123                       Herb
# 124                     Adrien
# 127                        NaN
# 128                    Michael
# 131                      Andee
#
#                                                    loc  \
# 2                                    114 12th Avenue N
# 3                                     616 17th Ave. N.
# 5                                   202 South 17th St.
# 10                               3020 Charlotte Avenue
# 16   1st Avenue (under John Seigenthaler Pedestrian...
# 19                          East Park Community Center
# 26                    500 East Iris Dr., Nashville, TN
# 28                              1524 Demonbreun Street
# 29                       21st Avenue and Belcourt Ave.
# 39                                  Church Street Park
# 40       In the Alley between 4th and 5th off of Union
# 42                                1602 21st Ave. South
# 44                             2700 12th Avenue South.
# 45                                       1306 McGavock
# 46                                    1402 Clinton St.
# 47                                   2620 Lebanon Pike
# 54                                      300 4th Avenue
# 56                               702 Murfreesboro Pike
# 57                    100 Broadway, Nashville TN 37201
# 58                                   5207 Harding Pike
# 61                   Riverside Drive and McGavock Pike
# 63                                      625 8th Ave S.
# 64                               2195 Nolensville Pike
# 66                     615 Church Street, Nashville TN
# 75                     600 Church Street, Nashville TN
# 81                  3700 James Kay Lane, Hermitage, TN
# 84                                 1234 3rd Ave. South
# 97                                         615 Main St
# 111                                   917 Woodland St.
# 123                                827 Meridian Street
# 124                                 1702 8th Avenue S.
# 127                             1037 28th Avenue North
# 128                                3756 Nolensville Rd
# 131                                1704 Charlotte Ave.
#
#                                                 medium   Type  \
# 2                     Porter all-weather outdoor paint  Mural
# 3    Steel, brick, wood, and fabric on frostproof c...  Mural
# 5                                  House paint on wood  Mural
# 10                                       Acrylic Paint  Mural
# 16                Metallic paint on metal/found object  Mural
# 19                        interior wall paint on board  Mural
# 26                     Latex house paint on wood fence  Mural
